# %%
import os
from os.path import exists

import re
import numpy as np

import pandas as pd 
from collections import Counter, OrderedDict
import matplotlib.pyplot as plt

import seaborn as sns

# %% [markdown]
# # Ragas grouped by Rasas

# %%
path_rasa_list = '/Users/rhythmjain/GT-files/2-2/CompMus/ComputationalMusicology-TheRagaGuide/RagaList.xlsx'
raga_rasa = pd.read_excel(path_rasa_list)[['Raga', 'FileName', 'Rasa']]

display(raga_rasa)
display(raga_rasa.groupby(['Rasa']).count().sort_values('Raga', ascending=False).head(5))
# Out:
#                Raga                  FileName      Rasa
# 0            Abhogi           Abhogi_D1T1.txt     Virah
# 1             Adana            Adana_D1T2.txt      Veer
# 2      Ahir Bhairav     Ahir_bhairav_D1T3.txt    Bhakti
# 3   Alhaiya bilaval  Alhaiya_bilaval_D1T4.txt    Adbhut
# 4           Asavari          Asavari_D1T5.txt    Bhakti
# ..              ...                       ...       ...
# 69           Sohini                sohini.txt    Karuna
# 70       Sur Malhar            sur_malhar.txt    Adbhut
# 71      Tilak Kamod           tilak_kamod.txt     Hasya
# 72           Tilang                tilang.txt  Shringar
# 73            Yaman                 yaman.txt  Shringar
#
# [74 rows x 3 columns]
#           Raga  FileName
# Rasa
# Shringar    33        33
# Bhakti      11        11
# Karuna       7         7
# Adbhut       5         5
# Veer         5         5

# %%
def get_token_tallies(file):
    if exists(file)==False:
        return -1
    with open(file, 'r') as f:
        lines = f.readlines()
    for i in range(len(lines)):
        lines[i] = lines[i].strip()
    return lines
    
def plot_hist(file_with_lines):
    
    w = Counter(file_with_lines)
#     print(w.items())
#     print(OrderedDict(sorted(w.items())))
    w = OrderedDict(sorted(w.items()))
    
    plt.rcParams["figure.figsize"] = (20,3)
    plt.bar(w.keys(), w.values())
    plt.show()

def make_corr_arrays(file_with_lines):
    scale = ['1', '2-', '2', '3-', '3', '4', '4+', '5', '6-', '6', '7-', '7']
    w = Counter(file_with_lines)
    scale_degree_frequency=np.zeros(12)
    for i in range(len(scale)):
        if scale[i] in w.keys():
            scale_degree_frequency[i] = w[scale[i]]
         
    return scale_degree_frequency.astype(int)

def get_swara_distribution_per_raga(rasa_dataframe):
    raga_names = []
    rasa_swara_distribution_per_raga = np.empty((len(rasa_dataframe), 12))

    for i in rasa_dataframe.index:
        path = 'Analysis/deg_files/'+str(rasa_dataframe['FileName'].loc[i])+'.deg'
        rasa_lines = get_token_tallies(path)
        if rasa_lines == -1:
            continue
        raga_names.append(rasa_dataframe['Raga'].loc[i])
        rasa_lines = [line for line in rasa_lines if not re.search(r'[*]', line)]
        scale_deg_dist_rasa = make_corr_arrays(rasa_lines)
        rasa_swara_distribution_per_raga[i] = scale_deg_dist_rasa
    return rasa_swara_distribution_per_raga, raga_names

# %% [markdown]
# # Adbhut

# %%
adbhut = raga_rasa[raga_rasa['Rasa'] == 'Adbhut'].reset_index()[['Raga', 'FileName', 'Rasa']]
adbhut
# Out:
#               Raga                   FileName    Rasa
# 0  Alhaiya bilaval   Alhaiya_bilaval_D1T4.txt  Adbhut
# 1            Bahar             Bahar_D1T7.txt  Adbhut
# 2           Basant            Basant_D1T8.txt  Adbhut
# 3  Miyan ki Malhar  Miyan_ki_malhar_D3T15.txt  Adbhut
# 4       Sur Malhar             sur_malhar.txt  Adbhut

# %%
R1 = np.corrcoef(adbhut_corr_matrix)
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels=adbhut['Raga'].tolist(),
                      yticklabels=adbhut['Raga'].tolist());
heatmap.set_title('Adbhut Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Shringar

# %%
shringar = raga_rasa[raga_rasa['Rasa'] == 'Shringar'].reset_index()[['Raga', 'FileName', 'Rasa']]

shringar_swara_distribution_per_raga, raga_names = get_swara_distribution_per_raga(shringar)
R1 = np.corrcoef(shringar_swara_distribution_per_raga)
plt.figure(figsize=(20, 20))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels = raga_names,
                      yticklabels = raga_names);
heatmap.set_title('Shringar Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);
# Out:
# /opt/homebrew/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: divide by zero encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/lib/python3.10/site-packages/numpy/lib/function_base.py:2853: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /opt/homebrew/lib/python3.10/site-packages/numpy/lib/function_base.py:2854: RuntimeWarning: divide by zero encountered in divide
#   c /= stddev[None, :]

# %%
veer = raga_rasa[raga_rasa['Rasa'] == 'Veer'].reset_index()[['Raga', 'FileName', 'Rasa']]

veer_swara_distribution_per_raga, raga_names = get_swara_distribution_per_raga(veer)
R1 = np.corrcoef(veer_swara_distribution_per_raga)
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels = raga_names,
                      yticklabels = raga_names);
heatmap.set_title('Veer Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Veer

# %%
veer = raga_rasa[raga_rasa['Rasa'] == 'Veer'].reset_index()[['Raga', 'FileName', 'Rasa']]

veer_swara_distribution_per_raga, raga_names = get_swara_distribution_per_raga(veer)
R1 = np.corrcoef(veer_swara_distribution_per_raga)
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels = raga_names,
                      yticklabels = raga_names);
heatmap.set_title('Veer Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Bhakti

# %%
#bhakti or devotion

bhakti = raga_rasa[raga_rasa['Rasa'] == 'Bhakti'].reset_index()[['Raga', 'FileName', 'Rasa']]

bhakti_swara_distribution_per_raga, raga_names = get_swara_distribution_per_raga(bhakti)
R1 = np.corrcoef(bhakti_swara_distribution_per_raga)
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels = raga_names,
                      yticklabels = raga_names);
heatmap.set_title('Bhakti Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);

# %% [markdown]
# # Karuna

# %%
# Karuna or Sadness


karuna = raga_rasa[raga_rasa['Rasa'] == 'Karuna'].reset_index()[['Raga', 'FileName', 'Rasa']]

karuna_swara_distribution_per_raga, raga_names = get_swara_distribution_per_raga(karuna)
R1 = np.corrcoef(karuna_swara_distribution_per_raga)
plt.figure(figsize=(15, 10))
heatmap = sns.heatmap(R1, annot=True, vmin=-1, vmax=1, 
                      cmap="crest", 
                      xticklabels = raga_names,
                      yticklabels = raga_names);
heatmap.set_title('Karuna Correlation between 5 ragas',
                  fontdict={'fontsize':12}, pad=12);

# %%
for i in shringar.index:
    path= 'Analysis/deg_files/'+str(shringar['FileName'].loc[i])+'.deg'

    shringar_lines = get_token_tallies(path)
    if shringar_lines == -1:
        print("File:",str(shringar['FileName'].loc[i]), ".deg does not exist")

    else:
        shringar_lines = [line for line in shringar_lines if not re.search(r'[*]', line) ]
        print(shringar['Raga'].loc[i])
        plot_hist(shringar_lines)
# Out:
# totallines:  214 unique 11
# Bageshri
# totallines:  43 unique 11
# Bhimpalasi
# totallines:  161 unique 12
# Bihag
# totallines:  131 unique 10
# Brindabani Sarang
# totallines:  97 unique 9
# Chandrakauns
# File: Darbari_kanada_D2T3.txt .deg does not exist
# totallines:  53 unique 11
# Deshi
# totallines:  31 unique 9
# Durga
# totallines:  186 unique 12
# Gaud Malhar
# totallines:  45 unique 10
# Gaud Sarang
# totallines:  110 unique 10
# Gorakh Kalyan
# totallines:  29 unique 10
# Gujari Todi
# totallines:  85 unique 10
# Hansadhvani
# File: Jaunpuri_D2T17.txt .deg does not exist
# totallines:  213 unique 12
# Jhinjhoti
# totallines:  243 unique 12
# Jog
# totallines:  103 unique 11
# Kaafi
# totallines:  134 unique 12
# Khamaj
# totallines:  93 unique 12
# Kirvani
# totallines:  37 unique 11
# Madhuvanti
# totallines:  115 unique 12
# Manj khamaj
# totallines:  48 unique 12
# Maru Bihag
# totallines:  69 unique 9
# Megh
# totallines:  43 unique 10
# Nayaki kanada
# totallines:  205 unique 15
# Pilu
# totallines:  208 unique 11
# Rageshri
# totallines:  199 unique 12
# Shahana
# totallines:  223 unique 13
# Shuddh Kalyan
# totallines:  47 unique 11
# Shuddh Sarang
# totallines:  80 unique 12
# Shyam Kalyan
# totallines:  104 unique 12
# Sindhura
# totallines:  30 unique 10
# Tilang
# totallines:  37 unique 12
# Yaman

# %%
exists('Analysis/deg_files/Darbari_kanada_D2T3.txt.deg')
# Out:
# False

# %%
# shahana.txt
exists('Analysis/deg_files/shahana.txt.deg')
# Out:
# True
