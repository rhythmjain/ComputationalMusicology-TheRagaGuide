# %%
import os
import re

# %%
def get_cleaned_lines(lines):
    final_list=[]
    for line in lines:
#         print("line:", line)
        if (re.search(r'[\^*]',line)):
#             print("     Appending:", line)
            final_list.append(line)
            continue
        if len(line) == 1 :
#             print("     Appending:", line)
            final_list.append(line)
        elif len(line) == 2:
            if line[0] == '(':
                final_list.append(line[0])
                final_list.append(line[1])
            else:
                final_list.append(line)            
        else:
            s=1
            while(s < len(line)):
                bigram = line[s-1:s+1]
#                 print("     s:", s, "bigram:",bigram)
                if bigram in swara_vocab:
#                     print("     Appending:", bigram)
                    final_list.append(bigram)
                    s=s+2
                else:
#                     print("     else Appending:", line[s-1])
                    final_list.append(line[s-1])
                    s=s+1
                if s == len(line) :
#                     print("     s:", s, "line[s-1]:", line[s-1])
                    if line[s-1] in swara_vocab:
                        final_list.append(line[s-1])
                        s= s+1
    return final_list

# %%
path_src = 'raga_files'
path_dst = 'clean_files'
path_dst2 = 'clean_files_final'

swara_vocab = [ 'S', 'R', 'G', 'M', 'P', 'D', 'N',
                's','r','g','m','p','d','n', 
                'ss','rr','gg','mm','pp','dd','nn', 'hr','hN' ',', ')', '('
              ]

files = os.listdir(path_src)
for file in files:
    print(f"Cleaning#1:removing unwanted characters {file}")
    str_ = f'grep -v "linebreak" {path_src}/{file} | grep -v "discrep" |sed  \'s;[q.\\\/—~];;g\' > {path_dst}/{file}'
    os.system(str_)
    


for ind in range(len(files)):
    lines = []
    print(f"Cleaning {files[ind]}")
    with open(f'{path_dst}/{files[ind]}') as f:
        lines=(f.readlines())
    lines = [line.strip() for line in lines]
    final_list=get_cleaned_lines(lines)
    with open(path_dst2+'/'+files[ind], 'w+') as f:
        for final_list_line in final_list:
            f.write(f'{final_list_line}\n')
# Out:
# Cleaning#1:removing unwanted characters Basant_D1T8.txt
# Cleaning#1:removing unwanted characters Deshi_D2T5.txt
# Cleaning#1:removing unwanted characters Adana_D1T2.txt
# Cleaning#1:removing unwanted characters rageshri.txt
# Cleaning#1:removing unwanted characters Marva_D3T13.txt
# Cleaning#1:removing unwanted characters Hindol_D2T15.txt
# Cleaning#1:removing unwanted characters Ahir_bhairav_D1T3.txt
# Cleaning#1:removing unwanted characters Miyan_ki_todi_D3T16.txt
# Cleaning#1:removing unwanted characters Dhani_D2T6.txt
# Cleaning#1:removing unwanted characters Kedar_D3T5.txt
# Cleaning#1:removing unwanted characters Brindabani_sarang_D1T18.txt
# Cleaning#1:removing unwanted characters Bibhas_D1T15.txt
# Cleaning#1:removing unwanted characters Bhatiyar_D1T11.txt
# Cleaning#1:removing unwanted characters tilang.txt
# Cleaning#1:removing unwanted characters alap_data.txt
# Cleaning#1:removing unwanted characters yaman.txt
# Cleaning#1:removing unwanted characters shuddh_kalyan.txt
# Cleaning#1:removing unwanted characters Jaijaivanti_D2T16.txt
# Cleaning#1:removing unwanted characters Gunakri_D2T12.txt
# Cleaning#1:removing unwanted characters shri.txt
# Cleaning#1:removing unwanted characters puriya_dhanashri.txt
# Cleaning#1:removing unwanted characters Bhupali_D1T14.txt
# Cleaning#1:removing unwanted characters shahana.txt
# Cleaning#1:removing unwanted characters Gorakh_kalyan_D2T10.txt
# Cleaning#1:removing unwanted characters sur_malhar.txt
# Cleaning#1:removing unwanted characters Desh_D2T4.txt
# Cleaning#1:removing unwanted characters Bhairav_D1T9.txt
# Cleaning#1:removing unwanted characters puriya_kalyan.txt
# Cleaning#1:removing unwanted characters shankara.txt
# Cleaning#1:removing unwanted characters Kamod_D3T4.txt
# Cleaning#1:removing unwanted characters shuddh_sarang.txt
# Cleaning#1:removing unwanted characters Maru_bihag_D3T12.txt
# Cleaning#1:removing unwanted characters Bhimpalasi_D1T12.txt
# Cleaning#1:removing unwanted characters Jog_D3T1.txt
# Cleaning#1:removing unwanted characters Chandrakauns_D2T1.txt
# Cleaning#1:removing unwanted characters Chayanat_D2T2.txt
# Cleaning#1:removing unwanted characters Bilaskhani_todi_D1T17.txt
# Cleaning#1:removing unwanted characters tilak_kamod.txt
# Cleaning#1:removing unwanted characters Nayaki_kanada_D3T18.txt
# Cleaning#1:removing unwanted characters Hansadhvani_D2T14.txt
# Cleaning#1:removing unwanted characters Abhogi_D1T1.txt
# Cleaning#1:removing unwanted characters sindhura.txt
# Cleaning#1:removing unwanted characters Bhupal_todi_D1T13.txt
# Cleaning#1:removing unwanted characters score_data.txt
# Cleaning#1:removing unwanted characters Madhuvanti_D3T9.txt
# Cleaning#1:removing unwanted characters Asavari_D1T5.txt
# Cleaning#1:removing unwanted characters Kirvani_D3T7.txt
# Cleaning#1:removing unwanted characters Khamaj_D3T6.txt
# Cleaning#1:removing unwanted characters Jaunpuri_D2T17.txt
# Cleaning#1:removing unwanted characters Jogiya_D3T2.txt
# Cleaning#1:removing unwanted characters Bahar_D1T7.txt
# Cleaning#1:removing unwanted characters Bihag_D1T16.txt
# Cleaning#1:removing unwanted characters Multani_D3T17.txt
# Cleaning#1:removing unwanted characters sdmarkov-output.txt
# Cleaning#1:removing unwanted characters Miyan_ki_malhar_D3T15.txt
# Cleaning#1:removing unwanted characters Jhinjhoti_D2T18.txt
# Cleaning#1:removing unwanted characters puriya.txt
# Cleaning#1:removing unwanted characters Manj_khamaj_D3T11.txt
# Cleaning#1:removing unwanted characters sohini.txt
# Cleaning#1:removing unwanted characters shyam_kalyan.txt
# Cleaning#1:removing unwanted characters Gaud_sarang_D2T9.txt
# Cleaning#1:removing unwanted characters Gaud_malhar_D2T8.txt
# Cleaning#1:removing unwanted characters Bageshri_D1T6.txt
# Cleaning#1:removing unwanted characters append_ending.sh
# Cleaning#1:removing unwanted characters Pilu_D3T20.txt
# Cleaning#1:removing unwanted characters Durga_D2T7.txt
# Cleaning#1:removing unwanted characters Malkauns_D3T10.txt
# Cleaning#1:removing unwanted characters Lalit_D3T8.txt
# Cleaning#1:removing unwanted characters Gujari_todi_D2T11.txt
# Cleaning#1:removing unwanted characters Alhaiya_bilaval_D1T4.txt
# Cleaning#1:removing unwanted characters Bhairavi_D1T10.txt
# Cleaning#1:removing unwanted characters Kafi_D3T3.txt
# Cleaning#1:removing unwanted characters ramkali.txt
# Cleaning#1:removing unwanted characters Patdip_D3T19.txt
# Cleaning#1:removing unwanted characters Darbari_kanada_D2T3.txt
# Cleaning#1:removing unwanted characters Hamir_D2T13.txt
# Cleaning#1:removing unwanted characters Megh_D3T14.txt
# Cleaning#1:removing unwanted characters purvi.txt
# Cleaning Basant_D1T8.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 24
#      22     lines=(f.readlines())
#      23 lines = [line.strip() for line in lines]
# ---> 24 final_list=get_cleaned_lines(lines)
#      25 with open(path_dst2+'/'+files[ind], 'w+') as f:
#      26     for final_list_line in final_list:
#
# NameError: name 'get_cleaned_lines' is not defined

# %%
# Out:
# **raga
# *clefG2
# *k[b-,e-,a-,d-]
# *s[c,d,e-,f,,a,]
# s
# r
# g
# m
# p
# d
# n
# ss
# ,
# ss
# n
# d
# p
# m
# g
# r
# s
# ,
# hr
# g
# hr
# s
# s
# g
# hr
# m
# hr
# m
# g
# r
# g
# hr
# g
# hr
# s
# (
# g
# r
# N
# N
# D
# s
# N
# D
# )
# ,
# hr
# g
# hr
# (
# hr
# g
# hr
# g
# hr
# N)
# N
# ,
# (
# P
# N
# D
# N
# P
# N
# s
# g
# N
# g
# s
# N)
# (
# D
# P)
# P
# ,
# (
# P
# D)
# s
# s
# hr
# g
# hr
# m
# hr
# m
# g
# hr
# g
# r
# s
# r
# s
# (
# s
# g
# r
# s
# h
# N
# )
# s
# g
# r
# s
# r
# s
# ,
# N
# s
# g
# m
# p
# d
# p
# m
# g
# ,
# g
# r
# g
# p
# p
# (
# d
# p
# d
# m
# p
# n
# d)
# (
# p
# d)
# (
# p
# m)
# m
# (
# p
# m
# g
# hr
# g
# hr
# s
# hr
# s
# g)
# g
# ,
# g
# p
# (
# d
# ss
# )
# s
# ss
# (
# hr
# r
# ss
# n)
# (
# ss
# rr
# )
# (
# ss
# n)
# (
# d
# p
# d
# p
# )
# m
# g
# hr
# g
# g
# r
# s
# ,
# p
# p
# d
# (
# d
# p
# d
# p
# m)
# g
# s
# g
# s
# N
# (
# s
# g
# m
# p
# d
# p
# )
# (
# p
# m
# g)
# g
# ,
# (
# s
# g
# s
# g
# m
# p)
# (
# m
# g)
# m
# r
# s
# r
# sD
# (
# P
# D)
# s
# s
# r
# s
# g
# r
# m
# g
# r
# g
# (
# r
# s
# r
# s
# )
# (
# s
# r
# g
# r
# )
# s
# N
# s
# h
# N
# (
# g
# r)
# (
# r
# s)
# s
# *-

# %%
# Out:
# bCleaning Basant_D1T8.txt
# bCleaning Deshi_D2T5.txt
# bCleaning Adana_D1T2.txt
# bCleaning rageshri.txt
# bCleaning Marva_D3T13.txt
# bCleaning Hindol_D2T15.txt
# bCleaning Ahir_bhairav_D1T3.txt
# bCleaning Miyan_ki_todi_D3T16.txt
# bCleaning Dhani_D2T6.txt
# bCleaning Kedar_D3T5.txt
# bCleaning Brindabani_sarang_D1T18.txt
# bCleaning Bibhas_D1T15.txt
# bCleaning Bhatiyar_D1T11.txt
# bCleaning tilang.txt
# bCleaning alap_data.txt
# bCleaning yaman.txt
# bCleaning shuddh_kalyan.txt
# bCleaning Jaijaivanti_D2T16.txt
# bCleaning Gunakri_D2T12.txt
# bCleaning shri.txt
# bCleaning puriya_dhanashri.txt
# bCleaning Bhupali_D1T14.txt
# bCleaning shahana.txt
# bCleaning Gorakh_kalyan_D2T10.txt
# bCleaning sur_malhar.txt
# bCleaning Desh_D2T4.txt
# bCleaning Bhairav_D1T9.txt
# bCleaning puriya_kalyan.txt
# bCleaning shankara.txt
# bCleaning Kamod_D3T4.txt
# bCleaning shuddh_sarang.txt
# bCleaning Maru_bihag_D3T12.txt
# bCleaning Bhimpalasi_D1T12.txt
# bCleaning Jog_D3T1.txt
# bCleaning Chandrakauns_D2T1.txt
# bCleaning Chayanat_D2T2.txt
# bCleaning Bilaskhani_todi_D1T17.txt
# bCleaning tilak_kamod.txt
# bCleaning Nayaki_kanada_D3T18.txt
# bCleaning Hansadhvani_D2T14.txt
# bCleaning Abhogi_D1T1.txt
# bCleaning sindhura.txt
# bCleaning Bhupal_todi_D1T13.txt
# bCleaning score_data.txt
# bCleaning Madhuvanti_D3T9.txt
# bCleaning Asavari_D1T5.txt
# bCleaning Kirvani_D3T7.txt
# bCleaning Khamaj_D3T6.txt
# bCleaning Jaunpuri_D2T17.txt
# bCleaning Jogiya_D3T2.txt
# bCleaning Bahar_D1T7.txt
# bCleaning Bihag_D1T16.txt
# bCleaning Multani_D3T17.txt
# bCleaning sdmarkov-output.txt
# bCleaning Miyan_ki_malhar_D3T15.txt
# bCleaning Jhinjhoti_D2T18.txt
# bCleaning puriya.txt
# bCleaning Manj_khamaj_D3T11.txt
# bCleaning sohini.txt
# bCleaning shyam_kalyan.txt
# bCleaning Gaud_sarang_D2T9.txt
# bCleaning Gaud_malhar_D2T8.txt
# bCleaning Bageshri_D1T6.txt
# bCleaning append_ending.sh
# bCleaning Pilu_D3T20.txt
# bCleaning Durga_D2T7.txt
# bCleaning Malkauns_D3T10.txt
# bCleaning Lalit_D3T8.txt
# bCleaning Gujari_todi_D2T11.txt
# bCleaning Alhaiya_bilaval_D1T4.txt
# bCleaning Bhairavi_D1T10.txt
# bCleaning Kafi_D3T3.txt
# bCleaning ramkali.txt
# bCleaning Patdip_D3T19.txt
# bCleaning Darbari_kanada_D2T3.txt
# bCleaning Hamir_D2T13.txt
# bCleaning Megh_D3T14.txt
# bCleaning purvi.txt

# %%
path_dst2+'/'+file
# Out:
# 'clean_files_final/purvi.txt'
